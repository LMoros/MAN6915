# %% [markdown]
# ### Programming Assignment #3
#
# Using the iris data set (located in the Files/datasets folder of the webcourse), perform the following operations in order to answer the following question: "Given an iris flower's petal length, petal width, sepal length, and sepal width, what variable(s) should we look at if we wanted to predict the species of the flower?"

# %% [markdown]
# Read iris.txt into a data frame (2 point)

# %%
import pandas as pd
from pandas.tools.plotting import scatter_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

# the following two lines avoid getting warnings about pandas
# version changes and deprications
import warnings
warnings.filterwarnings('ignore')

dataset = pd.read_csv('./LuisMoros_Assignment3_data/iris.txt')

# %% [markdown]
# 2.1- Print the head the dataset (2 point)

# %%
# 2.1 Task
print(dataset.head())
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# 2.1- Interpretation: Dataset has 5 features, 4 are numeric and 1 categorical

# %% [markdown]
# 2.2 Print the tail of the dataset (2 point)

# %%
# 2.2 Task
print(dataset.tail(3))
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %% [markdown]
# 2.2- Interpretation:  there are 150 observations

# %% [markdown]
# 2.3- Print summary statistics for the data frame (both numeric and categorical columns) (2 point)

# %%
# 2.3 Task
print(dataset.describe())
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %% [markdown]
# 2.3- Interpretation:
#  - Sepal Length is close to a normal distirbution (median and mean are very close)
#  - Septal Width is close to a normal distribution and has the smallest variance of all the features
#  - Petal Length is left skewed and it has the largest variance of all the features
#  - Petal Width is a bit left skewed

# %% [markdown]
# 2.4- Generate a box plot for the data set (2 point)

# %%
#2.4 Task

#ignore resulting object as only plot is required
ignore = dataset.boxplot() # show boxplot

# %% [markdown]
# 2.5- Interpretation:
#  - Sepal Width has more out layers
#  - Petal Length has a large variance and is very left skewed

# %% [markdown]
# 2.5- Generate a line plot the dataset (2 point)

# %%
#2.5 task
axes = dataset.plot()
axes.set_xlabel('observations')
ignore = axes.set_ylabel('values')

# %% [markdown]
# 2.5- Interpretation: petal width and specially petal length seem to have a multimodal distribution

# %% [markdown]
# 2.6- Generate a histogram of the dataset (2 point)

# %%
#2.6 task
axes= dataset.hist()

# %% [markdown]
# 2.6- Interpretation:
#     - Petal Length has a multimodal distribution with peaks around 1 and 5
#     - Petal Width has a multimodal distribution with peaks around 0.5, 1.5,
#       and 2.0

# %% [markdown]
# 3- Group the data on the Species column and explore the partitioned dataset

# %% [markdown]
# 3.1 - Print the summary statistics for each species in the dataset (2 point)

# %%
dataset.groupby('Species').describe()
# Out:
#                        PetalLength  PetalWidth  SepalLength  SepalWidth
# Species
# Iris-setosa     count    50.000000   50.000000    50.000000   50.000000
#                 mean      1.464000    0.244000     5.006000    3.418000
#                 std       0.173511    0.107210     0.352490    0.381024
#                 min       1.000000    0.100000     4.300000    2.300000
#                 25%       1.400000    0.200000     4.800000    3.125000
#                 50%       1.500000    0.200000     5.000000    3.400000
#                 75%       1.575000    0.300000     5.200000    3.675000
#                 max       1.900000    0.600000     5.800000    4.400000
# Iris-versicolor count    50.000000   50.000000    50.000000   50.000000
#                 mean      4.260000    1.326000     5.936000    2.770000
#                 std       0.469911    0.197753     0.516171    0.313798
#                 min       3.000000    1.000000     4.900000    2.000000
# ...

# %% [markdown]
# 3.1- Interpretation:
# - When group by Species,  the distribution of all features is much closer to a normal distribution. Each species has a different mean and median (central tendency) on all features

# %% [markdown]
# 3.2 Generate a boxplot for each species in the dataset (2 point)

# %%
ignore=dataset.boxplot(by='Species',layout=(4,1),figsize=(6,12))

# %% [markdown]
# 3.2- Interpretation:
# - The most drastic difference between Species is observed in their Petal Lengths.

# %% [markdown]
# 3.3- Generate a scatter matrix for the dataset (2 point)

# %%
#3.3 task
ignore=scatter_matrix(dataset)

# %% [markdown]
# 3.3- Interpretation:
# - The highest correlation is observed between Petal Length and Petal Width.
# - The second highest correlation is observed between Petal Length and Sepal Length.

# %% [markdown]
# 4- Provide an answer to the analysis question based on your interpretation of the data (2 point)

# %% [markdown]
# Grouping by "Species" clearly shows"Petal Length" as the most contrasting feature between the sampled species.  It would be recomended to use this feature to infer the Species of an unspecified species observation.
